# %% [markdown]
# # Using `raw_input` and `%debug` in the Notebook
#
# The Notebook has added support for `raw_input` and `%debug`, as of 1.0.

# %%
# Python 3 compat
import sys
if sys.version_info[0] >= 3:
    raw_input = input

# %%
name = raw_input("What is your name? ")
name
# Out:
# What is your name?  Sir Ryan
# 'Sir Ryan'

# %%
def div(x, y):
    return x/y

div(1,0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [3], in <module>
#       1 def div(x, y):
#       2     return x/y
# ----> 4 div(1,0)
#
# Input In [3], in div(x, y)
#       1 def div(x, y):
# ----> 2     return x/y
#
# ZeroDivisionError: division by zero

# %%
# %debug
# Out:
# > /tmp/ipykernel_303/2531016680.py(2)div()
#       1 def div(x, y):
# ----> 2     return x/y
#       3
#       4 div(1,0)
# ipdb>  exit
